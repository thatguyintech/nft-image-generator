# %%
from PIL import Image 
from IPython.display import display 
import random
import json

# %%
attributes = {
    "accessories": {
        "150-Accessories": {
            "files": [
                "Banana",
                "blue chakra hands",
                "Boba",
                "Copy of Big Shruiken",
                "Copy of Big Sword",
                "Copy of Dual Katanas",
                "Copy of Korean Corn Dog",
                "Copy of Master Sword",
                "Copy of Pocky Sword",
                "green chakra hands",
                "red chakra hands"
            ],
            "weights": [
                10,
                9,
                9,
                9,
                9,
                9,
                9,
                9,
                9,
                9,
                9
            ]
        }
    },
    "background": {
        "0-background": {
            "files": [
                "BambooBackground",
                "blueSolidBackground",
                "greenSolidBackground",
                "Koi Background",
                "orangeSolidBackground",
                "purpleSolidBackground",
                "redSolidBackground",
                "StarsBackground",
                "SushiBackground",
                "SusuwatariBackground",
                "tealSolidBackground",
                "yellowSolidBackground"
            ],
            "weights": [
                9,
                9,
                9,
                9,
                8,
                8,
                8,
                8,
                8,
                8,
                8,
                8
            ]
        }
    },
    "body": {
        "10-body": {
            "files": [
                "Copy of Body"
            ],
            "weights": [
                100
            ]
        }
    },
    "bottom": {
        "20-bottoms under shoes": {
            "files": [
                "Copy of Black Dress Pants",
                "Copy of Black Joggers",
                "Copy of Black Skinny Bottom",
                "Copy of Blue Skinny Bottom",
                "Copy of Blue Skinny Jeans",
                "Copy of Soccer Pants",
                "Copy of White Skinny Bottom"
            ],
            "weights": [
                15,
                15,
                14,
                14,
                14,
                14,
                14
            ]
        },
        "40-bottom over shoe": {
            "files": [
                "Copy of Bball Shorts",
                "Copy of Black Wide Bottom",
                "Copy of Blue Wide Bottom",
                "Copy of Blue Wide Jeans",
                "Copy of Gray Sweatpants",
                "Copy of Heart Boxers",
                "Copy of Jean Shorts",
                "Copy of Light Denim Shorts Shorts",
                "Copy of Olive Utility Pants",
                "Copy of Red Sheesh Speedo",
                "Copy of White Wide Bottom"
            ],
            "weights": [
                10,
                9,
                9,
                9,
                9,
                9,
                9,
                9,
                9,
                9,
                9
            ]
        }
    },
    "cheek": {
        "90-cheek": {
            "files": [
                "Copy of curse",
                "Copy of freckles",
                "Copy of hallow",
                "Copy of lightBlush",
                "Copy of pinkCheeks",
                "Copy of swirlies",
                "Copy of whiskers"
            ],
            "weights": [
                15,
                15,
                14,
                14,
                14,
                14,
                14
            ]
        }
    },
    "eyes": {
        "130-eyes": {
            "files": [
                "Copy of angry",
                "Copy of bigandcute",
                "Copy of circles",
                "Copy of closed",
                "Copy of ded",
                "Copy of doubleLaser",
                "Copy of excited",
                "Copy of focused",
                "Copy of hearts",
                "Copy of normal",
                "Copy of satisfied",
                "Copy of singleLaser",
                "Copy of skeptical",
                "Copy of soHappy",
                "Copy of tears",
                "Copy of terrified",
                "Copy of unamused",
                "Copy of wideOpen"
            ],
            "weights": [
                6,
                6,
                6,
                6,
                6,
                6,
                6,
                6,
                6,
                6,
                5,
                5,
                5,
                5,
                5,
                5,
                5,
                5
            ]
        }
    },
    "face": {
        "70-face": {
            "files": [
                "Copy of face"
            ],
            "weights": [
                100
            ]
        }
    },
    "hair": {
        "100-hair": {
            "files": [
                "Copy of aLineBobBrown",
                "Copy of aLineBobPurple",
                "Copy of aLineBobRed",
                "Copy of bedheadSpikyBlue",
                "Copy of bedHeadSpikySilver",
                "Copy of bowlCut",
                "Copy of bunHairPink",
                "Copy of bunHairPurple",
                "Copy of bunHairRed",
                "Copy of cleanHair",
                "Copy of cocoonGold",
                "Copy of cocoonPink",
                "Copy of normalSpikyBlue",
                "Copy of normalSpikyDeepRed",
                "Copy of normalSpikyMagenta",
                "Copy of normalSpikyOrange",
                "Copy of rainbowButterflyHair",
                "Copy of shortCurlsBlonde",
                "Copy of shortCurlsBlue",
                "Copy of shortCurlsPlatinum",
                "Copy of threeHairs",
                "Copy of tiedHairBlack",
                "Copy of tiedHairBlue",
                "Copy of tiedHairRed",
                "Copy of upwardsSpikyRed",
                "Copy of upwardsSpikySilver",
                "Copy of upwardsSpikyYellow",
                "Copy of voluminousSpikyPurple",
                "Copy of voluminousSpikySunset",
                "Copy of voluminousSpikyTropical"
            ],
            "weights": [
                4,
                4,
                4,
                4,
                4,
                4,
                4,
                4,
                4,
                4,
                3,
                3,
                3,
                3,
                3,
                3,
                3,
                3,
                3,
                3,
                3,
                3,
                3,
                3,
                3,
                3,
                3,
                3,
                3,
                3
            ]
        },
        "120 - hair over outerwear": {
            "files": [
                "blue goddess hair",
                "blue long flowy hair",
                "cotton candy goddess hair",
                "green long flowy hair",
                "orange goddess hair",
                "orange long flowy hair",
                "pink goddess hair",
                "red angel hair",
                "sunset angel hair"
            ],
            "weights": [
                12,
                11,
                11,
                11,
                11,
                11,
                11,
                11,
                11
            ]
        }
    },
    "headband": {
        "80-headband": {
            "files": [
                "Copy of dragon",
                "Copy of fairy",
                "Copy of fire",
                "Copy of grass",
                "Copy of ice",
                "Copy of shadow",
                "Copy of sound",
                "Copy of thunder",
                "Copy of water",
                "Copy of wind"
            ],
            "weights": [
                10,
                10,
                10,
                10,
                10,
                10,
                10,
                10,
                10,
                10
            ]
        }
    },
    "mouth": {
        "140-mouth": {
            "files": [
                "Copy of 3",
                "Copy of jawDrop",
                "Copy of kitty",
                "Copy of lipBite",
                "Copy of neutral",
                "Copy of nosebleed",
                "Copy of openMouth",
                "Copy of smallSmile",
                "Copy of squiggly"
            ],
            "weights": [
                12,
                11,
                11,
                11,
                11,
                11,
                11,
                11,
                11
            ]
        }
    },
    "outerwear": {
        "110-outerwear over head": {
            "files": [
                "Copy of Sheesh Hoodie"
            ],
            "weights": [
                100
            ]
        },
        "60-outerwear under head": {
            "files": [
                "Blue Cloak",
                "Copy of Black Kimono",
                "Copy of Blue Kimono",
                "Copy of CroppedHoodie",
                "Copy of Green Armor",
                "Copy of Green Robe",
                "Copy of Purple Blue Sash Vest",
                "Copy of Shroud",
                "Copy of SWATVest",
                "Copy of Toga",
                "Copy of UtilityVest",
                "Copy of White Kimono",
                "Red Cloak",
                "Yellow Cloak"
            ],
            "weights": [
                8,
                8,
                7,
                7,
                7,
                7,
                7,
                7,
                7,
                7,
                7,
                7,
                7,
                7
            ]
        }
    },
    "shoes": {
        "30-shoes": {
            "files": [
                "Copy of Black Ninja Sandal",
                "Copy of Blue Ninja Sandal",
                "Copy of Clogs",
                "Copy of Converse",
                "Copy of Pink socks with sandals",
                "Copy of Red Heels",
                "Copy of Uggs ",
                "Copy of White Ninja Sandal",
                "Copy of White sneakers",
                "Copy of White Socks With Sandals",
                "Copy of Yellow Rainboots"
            ],
            "weights": [
                10,
                9,
                9,
                9,
                9,
                9,
                9,
                9,
                9,
                9,
                9
            ]
        }
    },
    "top": {
        "50-top": {
            "files": [
                "Copy of Bandage",
                "Copy of Bball Jersey",
                "Copy of Black Long Sleeve",
                "Copy of Black Mesh Top",
                "Copy of Blue Long Sleeve",
                "Copy of Naked Mesh Top",
                "Copy of Sheesh Essentials Shirt",
                "Copy of Sheesh Tank Top",
                "Copy of White Long Sleeve",
                "Copy of White Tee"
            ],
            "weights": [
                10,
                10,
                10,
                10,
                10,
                10,
                10,
                10,
                10,
                10
            ]
        }
    }
}

# %%
## Sanity check calculation on the total number of possible combos
def num_possible_combinations(all_attrs):
    total_combos = 1
    for category_name in all_attrs:
        category = all_attrs[category_name]
        num_files_in_category = 0
        for group_name in category:
            group = category[group_name]
            num_files_in_category += len(group["files"])
        total_combos *= num_files_in_category
    return total_combos

print(num_possible_combinations(attributes))
# Out:
# 1733836104000

# %%
## Generate Traits

# Number of random unique images we want to generate
TOTAL_IMAGES = 300

all_images = [] 

# A recursive function to generate unique image combinations.
# Keep track of trait counts as we generate.
def create_new_image():    
    new_image = {"attributes": []}
    
    # For each trait category, select a random trait based on the weightings 
    for category_name in attributes:
        category = attributes[category_name]
        
        # need to pick between groups if there are multiple
        num_files_in_category = 0
        group_name_to_use = ""
        group_names = []
        num_files_per_group = []
        weights_per_group = []
        for group_name in category:
            group_names.append(group_name)
            group = category[group_name]
            group_files = group["files"]
            num_files_in_category += len(group_files)
            num_files_per_group.append(len(group_files))
        # calculate implicit group weights via num_files_in_group/num_files_in_category but use whole nums
        for i in range(len(num_files_per_group)):
            g = num_files_per_group[i]
            c = num_files_in_category
            weights_per_group.append(g/c*100)
            
        group_name_to_use = random.choices(group_names, weights_per_group)[0]
        category[group_name_to_use]
        group = category[group_name_to_use]
        
        # pick the item to use for this attribute category
        filename = random.choices(group["files"], group["weights"])[0]
        new_image["attributes"].append({"trait_type": category_name, "group": group_name_to_use, "value": filename})
    
    if new_image in all_images:
        return create_new_image()
    else:
        return new_image
    
    
# Generate the unique combinations based on trait weightings
for i in range(TOTAL_IMAGES):
    new_trait_image = create_new_image()
    all_images.append(create_new_image())

# %%
# Returns true if all images are unique.
# This is just a sanity check.. the create_new_image function should be generating unique images already.
def all_images_unique(all_images):
    seen = list()
    return not any(i in seen or seen.append(i) for i in all_images)

print("Are all images unique?", all_images_unique(all_images))
# Out:
# Are all images unique? True

# %%
# Add token Id to each image
i = 0
for item in all_images:
    item["tokenId"] = i
    i = i + 1

# %%
for img in all_images:
    print(str(img) + "\n")
# Out:
# {'attributes': [{'trait_type': 'accessories', 'group': '150-Accessories', 'value': 'Banana'}, {'trait_type': 'background', 'group': '0-background', 'value': 'greenSolidBackground'}, {'trait_type': 'body', 'group': '10-body', 'value': 'Copy of Body'}, {'trait_type': 'bottom', 'group': '20-bottoms under shoes', 'value': 'Copy of Black Dress Pants'}, {'trait_type': 'cheek', 'group': '90-cheek', 'value': 'Copy of pinkCheeks'}, {'trait_type': 'eyes', 'group': '130-eyes', 'value': 'Copy of angry'}, {'trait_type': 'face', 'group': '70-face', 'value': 'Copy of face'}, {'trait_type': 'hair', 'group': '120 - hair over outerwear', 'value': 'cotton candy goddess hair'}, {'trait_type': 'headband', 'group': '80-headband', 'value': 'Copy of grass'}, {'trait_type': 'mouth', 'group': '140-mouth', 'value': 'Copy of openMouth'}, {'trait_type': 'outerwear', 'group': '60-outerwear under head', 'value': 'Copy of Toga'}, {'trait_type': 'shoes', 'group': '30-shoes', 'value': 'Copy of Uggs '}, {'trait_type':
# ...

# %%
from collections import Counter

counters = {}
for category_name in attributes:
    counters[category_name] = Counter()

for image in all_images:
    for trait in image["attributes"]:
        category_name = trait["trait_type"]
        filename = trait["value"]
        counters[category_name][filename] += 1

print("total number of images: ", TOTAL_IMAGES)
print("")

for category_name in counters:
    counter = counters[category_name]
    print(category_name,"weights ...")
    num_items_in_category = len(counter)
    
    category = attributes[category_name]
    
    all_filenames_in_category = []
    
    expected_weights_by_filename = {}

    num_files_in_category = 0
    num_files_by_group = {}
    
    expected_num_items_in_category = 0
    for group_name in category:
        group = category[group_name]
        all_filenames_in_category += group["files"]
        num_files = len(group["files"])
        num_files_in_category += num_files
        num_files_by_group[group_name] = num_files
        
        expected_num_items_in_category += len(attributes[category_name][group_name]["files"])
        
    print("num items in category : actual - {} expected - {}".format(num_items_in_category, expected_num_items_in_category))
          
    # calculate implicit group weights via num_files_in_group/num_files_in_category but use whole nums
    for group_name in category:
        g = num_files_by_group[group_name]
        c = num_files_in_category
        group_weight = g/c
        
        group = category[group_name]
        for i, filename in enumerate(group["files"]):
            file_weight = group["weights"][i]
            expected_weights_by_filename[filename] = group_weight * file_weight
    
    for filename in all_filenames_in_category:
        actual_weight = counter[filename] / TOTAL_IMAGES
        expected_weight = expected_weights_by_filename[filename]
        print(filename, ":", "actual -", int(actual_weight*100),"expected -",expected_weight)
    print("")
# Out:
# total number of images:  300
#
# accessories weights ...
# num items in category : actual - 11 expected - 11
# Banana : actual - 13 expected - 10.0
# blue chakra hands : actual - 7 expected - 9.0
# Boba : actual - 8 expected - 9.0
# Copy of Big Shruiken : actual - 8 expected - 9.0
# Copy of Big Sword : actual - 9 expected - 9.0
# Copy of Dual Katanas : actual - 10 expected - 9.0
# Copy of Korean Corn Dog : actual - 8 expected - 9.0
# Copy of Master Sword : actual - 8 expected - 9.0
# Copy of Pocky Sword : actual - 9 expected - 9.0
# green chakra hands : actual - 10 expected - 9.0
# red chakra hands : actual - 7 expected - 9.0
#
# background weights ...
# num items in category : actual - 12 expected - 12
# BambooBackground : actual - 6 expected - 9.0
# blueSolidBackground : actual - 10 expected - 9.0
# greenSolidBackground : actual - 9 expected - 9.0
# Koi Background : actual - 8 expected - 9.0
# orangeSolidBackground : actual - 8 expected - 8.0
# ...

# %%
def sortkey(group_name):
    return int(group_name.split("-")[0])

#### Generate Images    
for image in all_images:
    layers = []
    
    sorted_traits = sorted(image["attributes"], key=lambda x: sortkey(x["group"]))
    print("sorted_traits", sorted_traits)
    for trait in sorted_traits:
        filepath = f'./attributes/{trait["trait_type"]}/{trait["group"]}/{trait["value"]}.png'
        opened = Image.open(filepath).resize((1024, 1024)).convert('RGBA')
        layers.append(opened)
    
    composite = Image.alpha_composite(layers[0], layers[1])
    for i in range(2, len(layers)):
        composite = Image.alpha_composite(composite, layers[i])
        
    rgb_im = composite.convert('RGB')
    filename = str(image["tokenId"]) + ".png"
    rgb_im.save("./images/" + filename)
    print("generated: ", filename)
# Out:
# sorted_traits [{'trait_type': 'background', 'group': '0-background', 'value': 'greenSolidBackground'}, {'trait_type': 'body', 'group': '10-body', 'value': 'Copy of Body'}, {'trait_type': 'bottom', 'group': '20-bottoms under shoes', 'value': 'Copy of Black Dress Pants'}, {'trait_type': 'shoes', 'group': '30-shoes', 'value': 'Copy of Uggs '}, {'trait_type': 'top', 'group': '50-top', 'value': 'Copy of White Tee'}, {'trait_type': 'outerwear', 'group': '60-outerwear under head', 'value': 'Copy of Toga'}, {'trait_type': 'face', 'group': '70-face', 'value': 'Copy of face'}, {'trait_type': 'headband', 'group': '80-headband', 'value': 'Copy of grass'}, {'trait_type': 'cheek', 'group': '90-cheek', 'value': 'Copy of pinkCheeks'}, {'trait_type': 'hair', 'group': '120 - hair over outerwear', 'value': 'cotton candy goddess hair'}, {'trait_type': 'eyes', 'group': '130-eyes', 'value': 'Copy of angry'}, {'trait_type': 'mouth', 'group': '140-mouth', 'value': 'Copy of openMouth'}, {'trait_type': 'acces
# ...

# %%
#### Grab all generated filenames from the images folder. Sort by image number.
from os import walk

filenames = next(walk("./images"), (None, None, []))[2]
filenames = list(filter(lambda x: x[0] != '.', filenames))
print(len(filenames))
filenames = sorted(filenames, key=lambda x: int(x[:len(x)-4]))
print(filenames)
# Out:
# 300
# ...

# %%
#### Generate Incomplete Metadata for each Image    (add ipfs uris later)

metadata = []

for image in all_images:
    token_id = image["tokenId"]
    image["description"] = "Chibi Shinobis are the cutest ninjas to ever exist."
    image["name"] = f'Chibi Shinobi #{token_id}'
    with open(f'./metadata/{str(token_id)}', 'w') as outfile:
        json.dump(image, outfile, indent=4)
    
    
    metadata.append(image)
    
METADATA_FILE_NAME = './metadata/all-traits.json'; 
with open(METADATA_FILE_NAME, 'w') as outfile:
    json.dump(metadata, outfile, indent=4)

# %%
#### Upload each image as an individual CID in IPFS
# import requests
# import time
# import os

# # try it out on the first 5 images first
# # first_five = filenames[:5]
# # print(first_five)

# # use a timer to prevent rate limiting from pinata (time.time() is in seconds)
# start_time = time.time()
# print(start_time)

# i = 0
# while i < len(filenames):
#     filename = filenames[i]
#     filepath = "./2021-09-15/images/" + filename
#     current_time = time.time()
#     if current_time - start_time >= 2.5:
#         with open(filepath, 'rb') as loaded_file:
#             # print(os.stat(filepath).st_size/1000000)
#             response = requests.post("https://api.pinata.cloud/pinning/pinFileToIPFS", files={"file": loaded_file}, headers={'Authorization': 'Bearer eIUzI1NiIsInR5cCI6IkpXVCJ9.....UOaeN-YsNc-XYxFFJaXZ23NfTLM2OOpfdL9pIchj2eQ'})
#             print("{} - {}".format(i+323, response.json()["IpfsHash"]))
        
        
        
#         i+=1
    
#         start_time = current_time
# Out:
# 1631942681.763836
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/t2/yx3msvdj6ssc5tq980ltsgzw0000gp/T/ipykernel_65251/3259691006.py in <module>
#      21             # print(os.stat(filepath).st_size/1000000)
#      22             response = requests.post("https://api.pinata.cloud/pinning/pinFileToIPFS", files={"file": loaded_file}, headers={'Authorization': 'Bearer eIUzI1NiIsInR5cCI6IkpXVCJ9.....UOaeN-YsNc-XYxFFJaXZ23NfTLM2OOpfdL9pIchj2eQ'})
# ---> 23             print("{} - {}".format(i+323, response.json()["IpfsHash"]))
#      24
#      25
#
# KeyError: 'IpfsHash'

# %%
#### Generate Metadata for each Image    

# IMAGES_BASE_URI = "ipfs://"
# PROJECT_NAME = "Chibi Shinobi"

# trait_types = {
#     "0-background": "background",
#     "30-headbands": "headband",
#     "40-symbol": "symbol",
#     "50-eyes": "eyes",
#     "60-cheek": "cheek",
#     "70-mouth": "mouth",
#     "80-hair": "hair",
#     "90-top": "top",
#     "100-bottom": "bottom",
#     "110-shoe": "shoe"
# }

# def getAttribute(key, value):
#     return {
#         "trait_type": key,
#         "value": value
#     }

# def loadCIDs():
#     CIDs = {}
#     with open('./tokenCIDs') as cid_file:
#         lines = cid_file.readlines()
#         for line in lines:
#             parts = line.split(' - ')
#             token_id = int(parts[0])
#             token_cid = parts[1].strip()
#             CIDs[token_id] = token_cid
#     return CIDs

# cids = loadCIDs()
# print(cids)

# all_metadata = []

# import json
# metadatas = []
# with open('./metadata-chibishinobis-testrun/all-traits.json') as testrunmetadatas:
#     metadatas = json.load(testrunmetadatas)

# for tokenId, meta in enumerate(metadatas):
#     token = {
#         "tokenId": tokenId,
#         "description": "Chibi Shinobi are the cutest ninjas to ever exist.",
#         "image": "ipfs://" + cids[tokenId],
#         "name": "Chibi Shinobi #" + str(tokenId),
#         "attributes": meta["attributes"],
#         "ipfs_image": "ipfs://" + cids[tokenId],
#     }
#     with open('./metadata/' + str(token_id), 'w') as outfile:
#         json.dump(token, outfile, indent=4)
        
#     all_metadata.append(token)
    
# print()
    
# METADATA_FILE_NAME = './metadata/all-traits.json'; 
# with open(METADATA_FILE_NAME, 'w') as outfile:
#     json.dump(all_metadata, outfile, indent=4)

# # for i in all_images:

# #     token_id = i['tokenId']
# #     token = {
# #         "tokenId": token_id,
# #         "description": "Chibi Shinobi are the cutest ninjas to ever exist.",
# #         "image": IMAGES_BASE_URI + str(token_id) + '.png',
# #         "name": PROJECT_NAME + ' #' + str(token_id),
# #         "attributes": []
# #     }
# #     for attribute in i:
# #         if attribute not in trait_types:
# #             continue
# #         token["attributes"].append(getAttribute(trait_types[attribute], i[attribute]))

# #     with open('./metadata/' + str(token_id), 'w') as outfile:
# #         json.dump(token, outfile, indent=4)
        
# #     all_metadata.append(token)

# # METADATA_FILE_NAME = './metadata/all-traits.json'; 
# # with open(METADATA_FILE_NAME, 'w') as outfile:
# #     json.dump(all_metadata, outfile, indent=4)
# Out:
# {0: 'QmTiggBnSibkKKpHCquqWPn77KK8u1fW4dGJQAsdsLeAzH', 1: 'QmTo2j7xAcUR65W6rTN5exFw5yt8i6BbY6Ay6dWHmfgTyD', 2: 'QmPn6dg48pX1NiRv5uBkLR4i3nFPRAJMnNHtzDWBNMV7Ls', 3: 'QmbKzfga2tMKpvvaMWzWKeTEmnmXM3mBDVUnSxg74maurR', 4: 'QmdMu7iGfuedYD6HeZiAWPVQYXoTrJXiasbmoKCgr9kHmt', 5: 'Qmdch5FgRgddxXStqAd8Hk5TwbFbwFdfC2cKJSvyVc9i73', 6: 'QmazY1Dk6GHa9bbo7qGhiRyW28CDHLwq7dm1gXrHEzjtHq', 7: 'QmXGL5gssPaNMxsJ5VY1NTpFtzXbSkrCAy9bnrkN8xeQvw', 8: 'QmcJ7XHrmUW5XnWvAK2j6ZGE7UcFZAcJAAzrKap8qxaXAa', 9: 'QmdYB7W8ZaUwyNfL8vSicuBgsjyxPyAQs1gmf9dih3FVqK', 10: 'QmYMh1S16XTHg37i7hHm7sxTNH922xm27M2JKdM7Y3Fy6k', 11: 'QmWPwjcqUkdjJFV6S2Fw15gzuJB3qq35A3kLjMAsWDpdWy', 12: 'QmdXCo3NADTUzzSfh7DSfg3q9YpMXVgmrxfFj4PeuJaybm', 13: 'QmW1Bju7QtkHEXXA5E3p2c8fevFnXSyiLtFpRmu74fGqoX', 14: 'QmUunfnKrYM1wCVu1LHrugG5yWDeDK9tFbGCm5KEKa2nun', 15: 'QmVUSG8K2XXCtBAmAztiREb7M5zHLxB15VVUF22nNjycJC', 16: 'QmZchGTTLkohcrdVCFyqybxwAJSgjRExGL8uGiuPJMP7ag', 17: 'QmPKY2V7hywcC54YsqP611FmuGGVWQ4rXrieEJ6CL4HPb5', 18: 'QmaChuCYkTEJQFPzmCjU6UgMaDmkug
# ...
