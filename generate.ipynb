# %%
from PIL import Image 
from IPython.display import display 
import random
import json

# %%
# Each image is made up a series of traits
# The weightings for each trait drive the rarity and add up to 100%
#
# The traits should also be the file names, i.e. if the face file is:
# `./Chibishinobis09052021/1-face/f1.png`,
#
# then you should initialize the face traits array as:
# face = ["f1"]

attributes = {
    "1-face": {
        "files": ["f1"],
        "weights": [100]
    },
    "2-eyes": {
        "files": ["e1", "e2", "e3", "e4"],
        "weights": [7, 15, 15, 63]
    },
    "3-headbands": {
        "files": ["h1", "h2", "h3", "h4", "h5"],
        "weights": [5,15,18,22,40]
    },
    "4-innerheadband": {
        "files": ["i1"],
        "weights": [100]
    },
    "5-symbol": {
        "files": ["s1", "s2", "s3"],
        "weights": [57,29,14]
    },
    "6-cheek": {
        "files": ["c1", "c2", "c3", "c4", "c5"],
        "weights": [8,30,30,16,16]
    },
    "7-hair": {
        "files": ["hr1", "hr2", "hr3"],
        "weights": [15,60,25]
    }
}

# %%
## Sanity check calculation on the total number of possible combos
def num_possible_combinations(all_attrs):
    total_combos = 1
    for attribute in all_attrs:
        files = all_attrs[attribute]["files"]
        total_combos *= len(files)
    return total_combos

print(num_possible_combinations(attributes))
# Out:
# 900

# %%
## Generate Traits

# Number of random unique images we want to generate
TOTAL_IMAGES = 200

all_images = [] 

# A recursive function to generate unique image combinations.
# Keep track of trait counts as we generate.
def create_new_image():
    
    new_image = {}
    
    # For each trait category, select a random trait based on the weightings 
    for key in attributes:
        new_image[key] = random.choices(attributes[key]["files"], attributes[key]["weights"])[0]
    
    if new_image in all_images:
        return create_new_image()
    else:
        return new_image
    
    
# Generate the unique combinations based on trait weightings
for i in range(TOTAL_IMAGES): 
    new_trait_image = create_new_image()
    all_images.append(create_new_image())
    
print("generated", len(all_images), "images!")
# Out:
# generated 200 images!

# %%
# Returns true if all images are unique.
# This is just a sanity check.. the create_new_image function should be generating unique images already.
def all_images_unique(all_images):
    seen = list()
    return not any(i in seen or seen.append(i) for i in all_images)

print("Are all images unique?", all_images_unique(all_images))
# Out:
# Are all images unique? True

# %%
# Add token Id to each image
i = 0
for item in all_images:
    item["tokenId"] = i
    i = i + 1

# %%
for img in all_images:
    print(str(img) + "\n")
# Out:
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c5', '7-hair': 'hr3', 'tokenId': 0}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c3', '7-hair': 'hr2', 'tokenId': 1}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c3', '7-hair': 'hr3', 'tokenId': 2}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c2', '7-hair': 'hr2', 'tokenId': 3}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c2', '7-hair': 'hr2', 'tokenId': 4}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c2', '7-hair': 'hr3', 'tokenId': 5}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c3', '7-hair': 'hr2', 'tokenId': 6}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c2', '7-hair': 'hr2', 'tokenId': 7}
#
# {'1-face': 'f1', '2-eyes': 'e1', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c1', '7-hair': 'hr3', 'tokenId': 8}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c1', '7-hair': 'hr2', 'tokenId': 9}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h1', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c3', '7-hair': 'hr2', 'tokenId': 10}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c4', '7-hair': 'hr1', 'tokenId': 11}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c2', '7-hair': 'hr3', 'tokenId': 12}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c2', '7-hair': 'hr2', 'tokenId': 13}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c5', '7-hair': 'hr2', 'tokenId': 14}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c2', '7-hair': 'hr2', 'tokenId': 15}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c1', '7-hair': 'hr2', 'tokenId': 16}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c4', '7-hair': 'hr3', 'tokenId': 17}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c3', '7-hair': 'hr2', 'tokenId': 18}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c5', '7-hair': 'hr2', 'tokenId': 19}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c2', '7-hair': 'hr2', 'tokenId': 20}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c2', '7-hair': 'hr2', 'tokenId': 21}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c3', '7-hair': 'hr2', 'tokenId': 22}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c5', '7-hair': 'hr3', 'tokenId': 23}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c3', '7-hair': 'hr2', 'tokenId': 24}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c4', '7-hair': 'hr3', 'tokenId': 25}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c5', '7-hair': 'hr3', 'tokenId': 26}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c5', '7-hair': 'hr1', 'tokenId': 27}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c5', '7-hair': 'hr2', 'tokenId': 28}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c3', '7-hair': 'hr3', 'tokenId': 29}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c4', '7-hair': 'hr1', 'tokenId': 30}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c1', '7-hair': 'hr3', 'tokenId': 31}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h1', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c4', '7-hair': 'hr2', 'tokenId': 32}
#
# {'1-face': 'f1', '2-eyes': 'e1', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c4', '7-hair': 'hr2', 'tokenId': 33}
#
# {'1-face': 'f1', '2-eyes': 'e1', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c2', '7-hair': 'hr3', 'tokenId': 34}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c4', '7-hair': 'hr2', 'tokenId': 35}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c3', '7-hair': 'hr2', 'tokenId': 36}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c3', '7-hair': 'hr2', 'tokenId': 37}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c3', '7-hair': 'hr3', 'tokenId': 38}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c2', '7-hair': 'hr2', 'tokenId': 39}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c3', '7-hair': 'hr3', 'tokenId': 40}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c3', '7-hair': 'hr2', 'tokenId': 41}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c2', '7-hair': 'hr2', 'tokenId': 42}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c2', '7-hair': 'hr3', 'tokenId': 43}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c4', '7-hair': 'hr2', 'tokenId': 44}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c3', '7-hair': 'hr2', 'tokenId': 45}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c3', '7-hair': 'hr1', 'tokenId': 46}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c2', '7-hair': 'hr1', 'tokenId': 47}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c5', '7-hair': 'hr2', 'tokenId': 48}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c3', '7-hair': 'hr3', 'tokenId': 49}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c5', '7-hair': 'hr3', 'tokenId': 50}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c3', '7-hair': 'hr2', 'tokenId': 51}
#
# {'1-face': 'f1', '2-eyes': 'e1', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c2', '7-hair': 'hr2', 'tokenId': 52}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c5', '7-hair': 'hr2', 'tokenId': 53}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c1', '7-hair': 'hr3', 'tokenId': 54}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c4', '7-hair': 'hr2', 'tokenId': 55}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c2', '7-hair': 'hr3', 'tokenId': 56}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c5', '7-hair': 'hr2', 'tokenId': 57}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c1', '7-hair': 'hr2', 'tokenId': 58}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c5', '7-hair': 'hr1', 'tokenId': 59}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c3', '7-hair': 'hr2', 'tokenId': 60}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c3', '7-hair': 'hr3', 'tokenId': 61}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c3', '7-hair': 'hr2', 'tokenId': 62}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c4', '7-hair': 'hr3', 'tokenId': 63}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c5', '7-hair': 'hr2', 'tokenId': 64}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c2', '7-hair': 'hr2', 'tokenId': 65}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c1', '7-hair': 'hr2', 'tokenId': 66}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c3', '7-hair': 'hr1', 'tokenId': 67}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c4', '7-hair': 'hr3', 'tokenId': 68}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h1', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c2', '7-hair': 'hr1', 'tokenId': 69}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c2', '7-hair': 'hr2', 'tokenId': 70}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c1', '7-hair': 'hr3', 'tokenId': 71}
#
# {'1-face': 'f1', '2-eyes': 'e1', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c5', '7-hair': 'hr2', 'tokenId': 72}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c5', '7-hair': 'hr2', 'tokenId': 73}
#
# {'1-face': 'f1', '2-eyes': 'e1', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c3', '7-hair': 'hr2', 'tokenId': 74}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h1', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c4', '7-hair': 'hr2', 'tokenId': 75}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c3', '7-hair': 'hr3', 'tokenId': 76}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c4', '7-hair': 'hr3', 'tokenId': 77}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c2', '7-hair': 'hr3', 'tokenId': 78}
#
# {'1-face': 'f1', '2-eyes': 'e1', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c5', '7-hair': 'hr3', 'tokenId': 79}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c4', '7-hair': 'hr2', 'tokenId': 80}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c2', '7-hair': 'hr3', 'tokenId': 81}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c1', '7-hair': 'hr1', 'tokenId': 82}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c2', '7-hair': 'hr2', 'tokenId': 83}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c3', '7-hair': 'hr1', 'tokenId': 84}
#
# {'1-face': 'f1', '2-eyes': 'e1', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c2', '7-hair': 'hr2', 'tokenId': 85}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c5', '7-hair': 'hr2', 'tokenId': 86}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c5', '7-hair': 'hr2', 'tokenId': 87}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c4', '7-hair': 'hr3', 'tokenId': 88}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c3', '7-hair': 'hr1', 'tokenId': 89}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c5', '7-hair': 'hr2', 'tokenId': 90}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c5', '7-hair': 'hr2', 'tokenId': 91}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c3', '7-hair': 'hr2', 'tokenId': 92}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c2', '7-hair': 'hr2', 'tokenId': 93}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c3', '7-hair': 'hr2', 'tokenId': 94}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c4', '7-hair': 'hr2', 'tokenId': 95}
#
# {'1-face': 'f1', '2-eyes': 'e1', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c2', '7-hair': 'hr1', 'tokenId': 96}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c1', '7-hair': 'hr3', 'tokenId': 97}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c1', '7-hair': 'hr1', 'tokenId': 98}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c2', '7-hair': 'hr2', 'tokenId': 99}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c2', '7-hair': 'hr2', 'tokenId': 100}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c2', '7-hair': 'hr3', 'tokenId': 101}
#
# {'1-face': 'f1', '2-eyes': 'e1', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c4', '7-hair': 'hr3', 'tokenId': 102}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h1', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c1', '7-hair': 'hr3', 'tokenId': 103}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c5', '7-hair': 'hr3', 'tokenId': 104}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c3', '7-hair': 'hr1', 'tokenId': 105}
#
# {'1-face': 'f1', '2-eyes': 'e1', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c3', '7-hair': 'hr2', 'tokenId': 106}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c5', '7-hair': 'hr2', 'tokenId': 107}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c5', '7-hair': 'hr1', 'tokenId': 108}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c5', '7-hair': 'hr3', 'tokenId': 109}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c1', '7-hair': 'hr2', 'tokenId': 110}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c3', '7-hair': 'hr3', 'tokenId': 111}
#
# {'1-face': 'f1', '2-eyes': 'e1', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c2', '7-hair': 'hr2', 'tokenId': 112}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c2', '7-hair': 'hr2', 'tokenId': 113}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c4', '7-hair': 'hr2', 'tokenId': 114}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c2', '7-hair': 'hr3', 'tokenId': 115}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h1', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c2', '7-hair': 'hr3', 'tokenId': 116}
#
# {'1-face': 'f1', '2-eyes': 'e1', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c3', '7-hair': 'hr2', 'tokenId': 117}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c4', '7-hair': 'hr2', 'tokenId': 118}
#
# {'1-face': 'f1', '2-eyes': 'e1', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c1', '7-hair': 'hr1', 'tokenId': 119}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c2', '7-hair': 'hr2', 'tokenId': 120}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c3', '7-hair': 'hr1', 'tokenId': 121}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c5', '7-hair': 'hr2', 'tokenId': 122}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c4', '7-hair': 'hr2', 'tokenId': 123}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c2', '7-hair': 'hr1', 'tokenId': 124}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c2', '7-hair': 'hr2', 'tokenId': 125}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c2', '7-hair': 'hr2', 'tokenId': 126}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c1', '7-hair': 'hr2', 'tokenId': 127}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c4', '7-hair': 'hr1', 'tokenId': 128}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c3', '7-hair': 'hr2', 'tokenId': 129}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c2', '7-hair': 'hr3', 'tokenId': 130}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h1', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c3', '7-hair': 'hr2', 'tokenId': 131}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c2', '7-hair': 'hr1', 'tokenId': 132}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c5', '7-hair': 'hr1', 'tokenId': 133}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c2', '7-hair': 'hr3', 'tokenId': 134}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c4', '7-hair': 'hr3', 'tokenId': 135}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c3', '7-hair': 'hr1', 'tokenId': 136}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h1', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c3', '7-hair': 'hr1', 'tokenId': 137}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c2', '7-hair': 'hr3', 'tokenId': 138}
#
# {'1-face': 'f1', '2-eyes': 'e1', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c4', '7-hair': 'hr2', 'tokenId': 139}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c4', '7-hair': 'hr3', 'tokenId': 140}
#
# {'1-face': 'f1', '2-eyes': 'e1', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c3', '7-hair': 'hr1', 'tokenId': 141}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c5', '7-hair': 'hr3', 'tokenId': 142}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c4', '7-hair': 'hr2', 'tokenId': 143}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c2', '7-hair': 'hr3', 'tokenId': 144}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c1', '7-hair': 'hr2', 'tokenId': 145}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c1', '7-hair': 'hr2', 'tokenId': 146}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c2', '7-hair': 'hr2', 'tokenId': 147}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c3', '7-hair': 'hr2', 'tokenId': 148}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c5', '7-hair': 'hr2', 'tokenId': 149}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c2', '7-hair': 'hr1', 'tokenId': 150}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c3', '7-hair': 'hr2', 'tokenId': 151}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c4', '7-hair': 'hr2', 'tokenId': 152}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c1', '7-hair': 'hr2', 'tokenId': 153}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c3', '7-hair': 'hr2', 'tokenId': 154}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c4', '7-hair': 'hr2', 'tokenId': 155}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c4', '7-hair': 'hr3', 'tokenId': 156}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c2', '7-hair': 'hr2', 'tokenId': 157}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c5', '7-hair': 'hr2', 'tokenId': 158}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c3', '7-hair': 'hr2', 'tokenId': 159}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c3', '7-hair': 'hr3', 'tokenId': 160}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c4', '7-hair': 'hr1', 'tokenId': 161}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c5', '7-hair': 'hr1', 'tokenId': 162}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c2', '7-hair': 'hr1', 'tokenId': 163}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c4', '7-hair': 'hr2', 'tokenId': 164}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h1', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c5', '7-hair': 'hr3', 'tokenId': 165}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c2', '7-hair': 'hr3', 'tokenId': 166}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c3', '7-hair': 'hr1', 'tokenId': 167}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c3', '7-hair': 'hr2', 'tokenId': 168}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c2', '7-hair': 'hr3', 'tokenId': 169}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c4', '7-hair': 'hr1', 'tokenId': 170}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c1', '7-hair': 'hr2', 'tokenId': 171}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c3', '7-hair': 'hr2', 'tokenId': 172}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c3', '7-hair': 'hr3', 'tokenId': 173}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c4', '7-hair': 'hr2', 'tokenId': 174}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h1', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c5', '7-hair': 'hr2', 'tokenId': 175}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c2', '7-hair': 'hr1', 'tokenId': 176}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c3', '7-hair': 'hr1', 'tokenId': 177}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c2', '7-hair': 'hr3', 'tokenId': 178}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c2', '7-hair': 'hr2', 'tokenId': 179}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c3', '7-hair': 'hr1', 'tokenId': 180}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c4', '7-hair': 'hr2', 'tokenId': 181}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c3', '7-hair': 'hr2', 'tokenId': 182}
#
# {'1-face': 'f1', '2-eyes': 'e1', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c2', '7-hair': 'hr2', 'tokenId': 183}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c4', '7-hair': 'hr3', 'tokenId': 184}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c5', '7-hair': 'hr2', 'tokenId': 185}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c2', '7-hair': 'hr2', 'tokenId': 186}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c2', '7-hair': 'hr2', 'tokenId': 187}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h1', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c3', '7-hair': 'hr2', 'tokenId': 188}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h3', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c5', '7-hair': 'hr3', 'tokenId': 189}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c3', '7-hair': 'hr2', 'tokenId': 190}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c2', '7-hair': 'hr1', 'tokenId': 191}
#
# {'1-face': 'f1', '2-eyes': 'e1', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c5', '7-hair': 'hr2', 'tokenId': 192}
#
# {'1-face': 'f1', '2-eyes': 'e3', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c3', '7-hair': 'hr1', 'tokenId': 193}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c3', '7-hair': 'hr1', 'tokenId': 194}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c3', '7-hair': 'hr2', 'tokenId': 195}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h5', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c2', '7-hair': 'hr1', 'tokenId': 196}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's1', '6-cheek': 'c1', '7-hair': 'hr3', 'tokenId': 197}
#
# {'1-face': 'f1', '2-eyes': 'e2', '3-headbands': 'h4', '4-innerheadband': 'i1', '5-symbol': 's3', '6-cheek': 'c5', '7-hair': 'hr3', 'tokenId': 198}
#
# {'1-face': 'f1', '2-eyes': 'e4', '3-headbands': 'h2', '4-innerheadband': 'i1', '5-symbol': 's2', '6-cheek': 'c5', '7-hair': 'hr3', 'tokenId': 199}

# %%
from collections import Counter

counters = {}
for att in attributes:
    counters[att] = Counter()

for img in all_images:
    for att in attributes:
        counters[att][img[att]] += 1
        
for att in counters:
    print(att,"weights ...")
    counter = counters[att]
    total_weight = sum(counter.values())
    for file in attributes[att]["files"]:
        actual_weight = counter[file] / total_weight
        weight_index = attributes[att]["files"].index(file)
        expected_weight = attributes[att]["weights"][weight_index]
        print(file, ":", "actual -", int(actual_weight*100),"expected -",expected_weight)
    print("")
# Out:
# 1-face weights ...
# f1 : actual - 100 expected - 100
#
# 2-eyes weights ...
# e1 : actual - 9 expected - 7
# e2 : actual - 21 expected - 15
# e3 : actual - 19 expected - 15
# e4 : actual - 50 expected - 63
#
# 3-headbands weights ...
# h1 : actual - 5 expected - 5
# h2 : actual - 21 expected - 15
# h3 : actual - 20 expected - 18
# h4 : actual - 20 expected - 22
# h5 : actual - 33 expected - 40
#
# 4-innerheadband weights ...
# i1 : actual - 100 expected - 100
#
# 5-symbol weights ...
# s1 : actual - 48 expected - 57
# s2 : actual - 32 expected - 29
# s3 : actual - 19 expected - 14
#
# 6-cheek weights ...
# c1 : actual - 10 expected - 8
# c2 : actual - 27 expected - 30
# c3 : actual - 27 expected - 30
# c4 : actual - 17 expected - 16
# c5 : actual - 18 expected - 16
#
# 7-hair weights ...
# hr1 : actual - 18 expected - 15
# hr2 : actual - 53 expected - 60
# hr3 : actual - 28 expected - 25

# %%
from functools import reduce
    
#### Generate Images    
for image in all_images:
    #print("generating image: ", image["tokenId"])
    #print("loading layers...")
    layers = []
    for dirname, filename in image.items():
        if dirname == "tokenId":
            continue
        fullpath = f'./attributes/{dirname}/{filename}.png'
        opened = Image.open(fullpath).convert('RGBA')
        #print("opened layer at path:", fullpath)
        layers.append(opened)
    
    #print("composing image..")
    #print("adding layers 1 and 2")
    composite = Image.alpha_composite(layers[0], layers[1])
    for i in range(2, len(layers)):
        #print("adding layer", i+1)
        composite = Image.alpha_composite(composite, layers[i])
        
    rgb_im = composite.convert('RGB')
    file_name = str(image["tokenId"]+1) + ".png"
    rgb_im.save("./images/" + file_name)
    print("generated: ", file_name)
# Out:
# generated:  1.png
# generated:  2.png
# generated:  3.png
# generated:  4.png
# generated:  5.png
# generated:  6.png
# generated:  7.png
# generated:  8.png
# generated:  9.png
# generated:  10.png
# generated:  11.png
# generated:  12.png
# generated:  13.png
# generated:  14.png
# generated:  15.png
# generated:  16.png
# generated:  17.png
# generated:  18.png
# generated:  19.png
# generated:  20.png
# generated:  21.png
# generated:  22.png
# generated:  23.png
# generated:  24.png
# generated:  25.png
# generated:  26.png
# generated:  27.png
# generated:  28.png
# generated:  29.png
# generated:  30.png
# generated:  31.png
# generated:  32.png
# generated:  33.png
# generated:  34.png
# generated:  35.png
# generated:  36.png
# generated:  37.png
# generated:  38.png
# generated:  39.png
# generated:  40.png
# generated:  41.png
# generated:  42.png
# generated:  43.png
# generated:  44.png
# generated:  45.png
# generated:  46.png
# generated:  47.png
# generated:  48.png
# generated:  49.png
# generated:  50.png
# generated:  51.png
# generated:  52.png
# generated:  53.png
# generated:  54.png
# generated:  55.png
# generated:  56.png
# generated:  57.png
# generated:  58.png
# generated:  59.png
# generated:  60.png
# generated:  61.png
# generated:  62.png
# generated:  63.png
# generated:  64.png
# generated:  65.png
# generated:  66.png
# generated:  67.png
# generated:  68.png
# generated:  69.png
# generated:  70.png
# generated:  71.png
# generated:  72.png
# generated:  73.png
# generated:  74.png
# generated:  75.png
# generated:  76.png
# generated:  77.png
# generated:  78.png
# generated:  79.png
# generated:  80.png
# generated:  81.png
# generated:  82.png
# generated:  83.png
# generated:  84.png
# generated:  85.png
# generated:  86.png
# generated:  87.png
# generated:  88.png
# generated:  89.png
# generated:  90.png
# generated:  91.png
# generated:  92.png
# generated:  93.png
# generated:  94.png
# generated:  95.png
# generated:  96.png
# generated:  97.png
# generated:  98.png
# generated:  99.png
# generated:  100.png
# generated:  101.png
# generated:  102.png
# generated:  103.png
# generated:  104.png
# generated:  105.png
# generated:  106.png
# generated:  107.png
# generated:  108.png
# generated:  109.png
# generated:  110.png
# generated:  111.png
# generated:  112.png
# generated:  113.png
# generated:  114.png
# generated:  115.png
# generated:  116.png
# generated:  117.png
# generated:  118.png
# generated:  119.png
# generated:  120.png
# generated:  121.png
# generated:  122.png
# generated:  123.png
# generated:  124.png
# generated:  125.png
# generated:  126.png
# generated:  127.png
# generated:  128.png
# generated:  129.png
# generated:  130.png
# generated:  131.png
# generated:  132.png
# generated:  133.png
# generated:  134.png
# generated:  135.png
# generated:  136.png
# generated:  137.png
# generated:  138.png
# generated:  139.png
# generated:  140.png
# generated:  141.png
# generated:  142.png
# generated:  143.png
# generated:  144.png
# generated:  145.png
# generated:  146.png
# generated:  147.png
# generated:  148.png
# generated:  149.png
# generated:  150.png
# generated:  151.png
# generated:  152.png
# generated:  153.png
# generated:  154.png
# generated:  155.png
# generated:  156.png
# generated:  157.png
# generated:  158.png
# generated:  159.png
# generated:  160.png
# generated:  161.png
# generated:  162.png
# generated:  163.png
# generated:  164.png
# generated:  165.png
# generated:  166.png
# generated:  167.png
# generated:  168.png
# generated:  169.png
# generated:  170.png
# generated:  171.png
# generated:  172.png
# generated:  173.png
# generated:  174.png
# generated:  175.png
# generated:  176.png
# generated:  177.png
# generated:  178.png
# generated:  179.png
# generated:  180.png
# generated:  181.png
# generated:  182.png
# generated:  183.png
# generated:  184.png
# generated:  185.png
# generated:  186.png
# generated:  187.png
# generated:  188.png
# generated:  189.png
# generated:  190.png
# generated:  191.png
# generated:  192.png
# generated:  193.png
# generated:  194.png
# generated:  195.png
# generated:  196.png
# generated:  197.png
# generated:  198.png
# generated:  199.png
# generated:  200.png

# %%
#### Write the Metadata for all Traits out to a file
METADATA_FILE_NAME = './metadata/all-traits.json'; 
with open(METADATA_FILE_NAME, 'w') as outfile:
    json.dump(all_images, outfile, indent=4)

# %%
#### Generate Metadata for each Image    

f = open('./metadata/all-traits.json',) 
data = json.load(f)


IMAGES_BASE_URI = "ADD_IMAGES_BASE_URI_HERE"
PROJECT_NAME = "ADD_PROJECT_NAME_HERE"

def getAttribute(key, value):
    return {
        "trait_type": key,
        "value": value
    }
for i in data:
    token_id = i['tokenId']
    token = {
        "image": IMAGES_BASE_URI + str(token_id) + '.png',
        "tokenId": token_id,
        "name": PROJECT_NAME + ' ' + str(token_id),
        "attributes": []
    }
    token["attributes"].append(getAttribute("Background", i["Background"]))
    token["attributes"].append(getAttribute("Circle", i["Circle"]))
    token["attributes"].append(getAttribute("Square", i["Square"]))

    with open('./metadata/' + str(token_id), 'w') as outfile:
        json.dump(token, outfile, indent=4)
f.close()
